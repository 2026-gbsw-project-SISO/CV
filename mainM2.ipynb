# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
model.train(data="/Users/jo-eunjin/Downloads/SISO/merged_dataset2/data.yaml", epochs=55, name="train20", imgsz=416, batch=2)
